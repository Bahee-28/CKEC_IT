# %%
n=int(input("Enter a Number:"))
tot=0
While(n>0):
    dig=n%10
tot=tot+dig
n=n/10
print("total:"tot)

# %%
#a="VLB Janakiammal college of arts and science"
a="hello world"
print(a)
print(a[5])
for x in "hello world":
    print (x)
a1="priya"
print(len(a1))
b="Hello,World"
print(b[:4])
a=" hello World "
print(a.upper())
print(a.lower())
print(a)
print(a.strip())
print(a.replace("W","H"))
c=[20,10,50,30,40]
c.sort()
print(c[-2])
print(min(c))
a=["sanusha","divya","shaliga","jemi"]
b=["nassrin","shifana","thansiya","akshitha"]
a.append(b)
print(a)
list=[10,11,12,13,14,15]
list.reverse()
print(list)
print(list(reversed(list)))
# Out:
# hello world
#
# h
# e
# l
# l
# o
#
# w
# o
# r
# l
# d
# 5
# Hell
#  HELLO WORLD
#  hello world
#  hello World
# hello World
#  hello Horld
# 40
# 10
# ['sanusha', 'divya', 'shaliga', 'jemi', ['nassrin', 'shifana', 'thansiya', 'akshitha']]
# [15, 14, 13, 12, 11, 10]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 28
#      26 list.reverse()
#      27 print(list)
# ---> 28 print(list(reversed(list)))
#
# TypeError: 'list' object is not callable

# %%
class habeeb:
    def find_arth(self,a=0,b=0):
        if a!=0 and b!=0:
            print("addition",(a+b))
            print("subraction",(a-b))
        elif a!=0:
            print("number",a)
        else:
            print("anu")
opj1=habeeb()
opj1.find_arth()
opj1.find_arth(1+2)
opj1.find_arth(2-1)
# Out:
# anu
# number 3
# number 1

# %%
basic=float(input("Enter the basic pay of the employee:")); 
da=float(input("Enter the da of the employee:")); 
hra=float(input("Enter the hra of the employee:")); 
tax=float(input("Enter the tax of the employee:")); 
employee="basic+da+hra+tax"; 
print("The employee slip") 
print("The basic pay of the employee is",basic) 
print("The da pay of the employee is",da) 
print("The hra pay of the employee is",hra) 
print("The tax pay of the employee is",tax) 
print("The total pay of the employee is",employee) 
print(eval(employee))
# Out:
# Enter the basic pay of the employee: 8888
# Enter the da of the employee: 5546
# Enter the hra of the employee: 2552
# Enter the tax of the employee: 55
# The employee slip
# The basic pay of the employee is 8888.0
# The da pay of the employee is 5546.0
# The hra pay of the employee is 2552.0
# The tax pay of the employee is 55.0
# The total pay of the employee is basic+da+hra+tax
# 17041.0

# %%
def newton_method(number,number_items=100): 
    a=float(number) 
for i in range(number_items): 
    number=0.5*(number+a/number) 
return number 
a=int(input("Enter the first number:")) 
b=int(input("Enter the second number:")) 
print("Square root of first number:",newton_method(a)) 
print("Square root of second number:",newton_method(b))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 3
#       1 def newton_method(number,number_items=100):
#       2     a=float(number)
# ----> 3 for i in range(number_items):
#       4     number=0.5*(number+a/number)
#       5 return number
#
# NameError: name 'number_items' is not defined
